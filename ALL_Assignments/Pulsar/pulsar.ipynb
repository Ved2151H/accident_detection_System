# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pulsar_data_train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12528 entries, 0 to 12527
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                12528 non-null  float64
#  1    Standard deviation of the integrated profile  12528 non-null  float64
#  2    Excess kurtosis of the integrated profile     10793 non-null  float64
#  3    Skewness of the integrated profile            12528 non-null  float64
#  4    Mean of the DM-SNR curve                      12528 non-null  float64
#  5    Standard deviation of the DM-SNR curve        11350 non-null  float64
#  6    Excess kurtosis of the DM-SNR curve           12528 non-null  float64
#  7    Skewness of the DM-SNR curve                  11903 non-null  float64
#  8   target_class                                   12528 non-null  float64
# dtypes: float64(9)
# ...

# %%
df.shape
# Out:
# (12528, 9)

# %%
df.tail()
# Out:
#         Mean of the integrated profile  \
# 12523                       124.312500
# 12524                       115.617188
# 12525                       116.031250
# 12526                       135.664062
# 12527                       120.726562
#
#         Standard deviation of the integrated profile  \
# 12523                                      53.179053
# 12524                                      46.784600
# 12525                                      43.213846
# 12526                                      49.933749
# 12527                                      50.472256
#
#         Excess kurtosis of the integrated profile  \
# 12523                                   -0.012418
# 12524                                    0.218177
# 12525                                    0.663456
# 12526                                   -0.089940
# 12527                                    0.346178
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# ...

# %%
df_1100 = df.sample(n=1100, random_state=42 )

# %%
df_1100.head(20)
# Out:
#         Mean of the integrated profile  \
# 7488                        121.421875
# 3776                        119.796875
# 6243                        133.257812
# 6123                        132.710938
# 4714                         94.906250
# 6671                         70.289062
# 5847                          6.937500
# 10413                       100.218750
# 4149                        102.632812
# 10523                       145.625000
# 10877                       129.726562
# 3393                         69.210938
# 6631                        114.664062
# 6745                        144.335938
# 10351                        49.078125
# 3616                        107.414062
# 828                         122.929688
# 741                         121.328125
# 6252                        101.640625
# 8990                        115.367188
#
#         Standard deviation of the integrated profile  \
# 7488                                       52.272664
# ...

# %%
df_1100.tail()
# Out:
#         Mean of the integrated profile  \
# 3896                        171.835938
# 10902                         6.500000
# 10660                        80.953125
# 8047                         98.695312
# 1575                        153.265625
#
#         Standard deviation of the integrated profile  \
# 3896                                       43.733886
# 10902                                      31.523057
# 10660                                      40.365877
# 8047                                       43.551614
# 1575                                       51.596009
#
#         Excess kurtosis of the integrated profile  \
# 3896                                    -0.788434
# 10902                                    7.124227
# 10660                                    0.474997
# 8047                                     0.360589
# 1575                                    -0.296755
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# ...

# %%
df_1100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1100 entries, 7488 to 1575
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                1100 non-null   float64
#  1    Standard deviation of the integrated profile  1100 non-null   float64
#  2    Excess kurtosis of the integrated profile     947 non-null    float64
#  3    Skewness of the integrated profile            1100 non-null   float64
#  4    Mean of the DM-SNR curve                      1100 non-null   float64
#  5    Standard deviation of the DM-SNR curve        981 non-null    float64
#  6    Excess kurtosis of the DM-SNR curve           1100 non-null   float64
#  7    Skewness of the DM-SNR curve                  1035 non-null   float64
#  8   target_class                                   1100 non-null   float64
# dtypes: float64(9)
# ...

# %%
df_1100.shape
# Out:
# (1100, 9)

# %% [markdown]
# # dealing with missing values

# %%
df_1100.isna().sum()
# Out:
#  Mean of the integrated profile                    0
#  Standard deviation of the integrated profile      0
#  Excess kurtosis of the integrated profile       153
#  Skewness of the integrated profile                0
#  Mean of the DM-SNR curve                          0
#  Standard deviation of the DM-SNR curve          119
#  Excess kurtosis of the DM-SNR curve               0
#  Skewness of the DM-SNR curve                     65
# target_class                                       0
# dtype: int64

# %%
df_1100.loc[:, :] = df_1100.fillna(df_1100.mean())

# %%
df_1100.isna().sum()
# Out:
#  Mean of the integrated profile                  0
#  Standard deviation of the integrated profile    0
#  Excess kurtosis of the integrated profile       0
#  Skewness of the integrated profile              0
#  Mean of the DM-SNR curve                        0
#  Standard deviation of the DM-SNR curve          0
#  Excess kurtosis of the DM-SNR curve             0
#  Skewness of the DM-SNR curve                    0
# target_class                                     0
# dtype: int64

# %%
df_1100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1100 entries, 7488 to 1575
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                1100 non-null   float64
#  1    Standard deviation of the integrated profile  1100 non-null   float64
#  2    Excess kurtosis of the integrated profile     1100 non-null   float64
#  3    Skewness of the integrated profile            1100 non-null   float64
#  4    Mean of the DM-SNR curve                      1100 non-null   float64
#  5    Standard deviation of the DM-SNR curve        1100 non-null   float64
#  6    Excess kurtosis of the DM-SNR curve           1100 non-null   float64
#  7    Skewness of the DM-SNR curve                  1100 non-null   float64
#  8   target_class                                   1100 non-null   float64
# dtypes: float64(9)
# ...

# %% [markdown]
# so all null values are removed

# %%
df_1100['target_class'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='target_class'>

# %%
df_1100.hist(figsize=(12, 10), bins=30)
plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=df_1100, x='target_class', y=' Mean of the integrated profile')
# Out:
# <Axes: xlabel='target_class', ylabel=' Mean of the integrated profile'>

# %%
sns.pairplot(df_1100, hue='target_class')

# %%
sns.kdeplot(data=df_1100, x=' Mean of the integrated profile', hue='target_class', fill=True)
# Out:
# <Axes: xlabel=' Mean of the integrated profile', ylabel='Density'>

# %%
#seperatng features and target
X = df_1100.drop('target_class', axis=1)
y = df_1100['target_class']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
#this centers the data around mean 0 and standard deviation 1

# %%
y.value_counts(normalize=True)
# Out:
# target_class
# 0.0    0.905455
# 1.0    0.094545
# Name: proportion, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(class_weight='balanced')

# %%
model = LogisticRegression(penalty='l1', solver='liblinear')
model.fit(X_scaled, y)
# Out:
# LogisticRegression(penalty='l1', solver='liblinear')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = model.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.9772727272727273
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99       199
#          1.0       1.00      0.76      0.86        21
#
#     accuracy                           0.98       220
#    macro avg       0.99      0.88      0.93       220
# weighted avg       0.98      0.98      0.98       220

# %%
import pandas as pd

sample_1 = np.array([[210.0, 120.0, 9.5, 6.2, 95.0, 70.0, 25.0, 1200.0]]) ## correct class is 1 
sample_2 = np.array([[180.0, 95.0, 6.8, 4.9, 78.0, 55.0, 18.5, 900.0]]) ## correct class is 0

sample_scaled = scaler.transform(sample_1)

pred = model.predict(sample_1)
prob = model.predict_proba(sample_1)

print("Predicted class:", pred[0])
# Out:
# Predicted class: 1.0
# d:\Subjects_Languages\Languages\AICT SureTrust Internship\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
