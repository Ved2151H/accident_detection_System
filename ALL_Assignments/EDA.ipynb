# %% [markdown]
# Loading of data set

# %%
import pandas as pd

# %%
df = pd.read_csv(r'SeoulBikeData.csv' ,encoding="latin1")

# %%
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0  01/12/2017                254     0             -5.2           37
# 1  01/12/2017                204     1             -5.5           38
# 2  01/12/2017                173     2             -6.0           39
# 3  01/12/2017                107     3             -6.2           40
# 4  01/12/2017                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
df.tail()
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 8755  30/11/2018               1003    19              4.2           34
# 8756  30/11/2018                764    20              3.4           37
# 8757  30/11/2018                694    21              2.6           39
# 8758  30/11/2018                712    22              2.1           41
# 8759  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 8755               2.6              1894                      -10.3
# 8756               2.3              2000                       -9.9
# 8757               0.3              1968                       -9.9
# 8758               1.0              1859                       -9.8
# 8759               1.3              1909                       -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# ...

# %% [markdown]
# what i got by seeing head and tail

# %% [markdown]
# total column are
# data , rented bike count , hour , temperature , humidity
#
#
# total no of row : 8759
# total no of column : 5

# %%
info = df.info()
print(info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       8760 non-null   object
#  1   Rented Bike Count          8760 non-null   int64
#  2   Hour                       8760 non-null   int64
#  3   Temperature(°C)            8760 non-null   float64
#  4   Humidity(%)                8760 non-null   int64
#  5   Wind speed (m/s)           8760 non-null   float64
#  6   Visibility (10m)           8760 non-null   int64
#  7   Dew point temperature(°C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)    8760 non-null   float64
#  9   Rainfall(mm)               8760 non-null   float64
#  10  Snowfall (cm)              8760 non-null   float64
#  11  Seasons                    8760 non-null   object
#  12  Holiday                    8760 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Date                         0
# Rented Bike Count            0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# dtype: int64

# %% [markdown]
# Max data hear

# %%
MaxBikeRentedHr = df['Rented Bike Count'].max()
print("maximum rented bike", MaxBikeRentedHr)

MaximimHrBikeRented = df["Hour"].max()
print("Hour of maximum bike rented:", MaximimHrBikeRented)
# Out:
# maximum rented bike 3556
# Hour of maximum bike rented: 23

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=df, x='Hour', y='Rented Bike Count')
plt.show()

# %% [markdown]
# this graph show the trend of time vs count .. hear the time is in 24 hr format  and this show between 15 to 20 the bike  rented is very high  that is form around 3 to 8 pm this can be because of school , office , college are ended

# %%
sns.regplot(x='Temperature(°C)', y='Rented Bike Count', data=df)
plt.show()

# %% [markdown]
# this graph shows that when temperature is low the bike rented is very less due to the -ve temperature customer prefer other vehicle then bike

# %% [markdown]
# BarPlot

# %%
sns.boxplot(data=df , x="Seasons" , y="Rented Bike Count")
plt.show()

# %% [markdown]
# this graph shows that in which season the bike rented is high because of ideal temperature

# %% [markdown]
# Scatter Plot

# %%
sns.scatterplot(data=df , x="Rainfall(mm)", y="Rented Bike Count"  )
plt.show()

# %% [markdown]
# this graph shows the relation between bike rented vs rainfall where there is rain no doubt the bike rented will be low due to rain , slipping

# %%
sns.scatterplot(data=df , x="Temperature(°C)" , y="Rented Bike Count")
plt.show()

# %% [markdown]
# this graph shows that when temperature is low the bike rented is very less due to the -ve temperature customer prefer other vehicle then bike ,[this is same as regplot but its scatter plot and each day is visible ]

# %% [markdown]
# heatmap

# %%
num_df = df.select_dtypes(include=['int64', 'float64'])


sns.heatmap(num_df.corr(), annot=True)
plt.show()

# %% [markdown]
# after seeing this we can get to know how the bike rented is affected and which are the factors that affect the bike renting (temperature , humidity and visibility)

# %%
sns.jointplot(x='Visibility (10m)', y='Rented Bike Count', data=df)
plt.show()

# %% [markdown]
# this graph show when visibility vs rented bike count when visibility is high the bike rented is also high although there are some outliers that rented bike even if visibility is low

# %%
sns.countplot(data=df , x="Holiday")
plt.show()

# %% [markdown]
# this graph shows that where there is non working day that is holiday bike rented are very low but where there is working day bike rented is high no holiday

# %%
sns.violinplot(data=df , x="Functioning Day" , y="Rented Bike Count")
plt.show()

# %% [markdown]
# THIS I  violineplot and it shows functioning day vs rented bike count and it is good then coutplot because of violinplot shows the spread of data to instade of just yes and no

# %%
sns.kdeplot(
    x=df["Visibility (10m)"],
    y=df["Rented Bike Count"],
    fill=True
)
plt.xlabel("Visibility (10m)")
plt.ylabel("Rented Bike Count")
plt.show()

# %% [markdown]
# this graph shows the relation of visibility vs rented bike count and its good for 'quick inside ' and its also ' clear '

# %%
sns.boxplot(data=df , x="Hour" , y ="Rented Bike Count")
# Out:
# <Axes: xlabel='Hour', ylabel='Rented Bike Count'>

# %% [markdown]
# for this we can see that at 8 in the morning and  18 there is high demand of rented bike its mostely because of Start and end of working hours

# %%
sns.stripplot(x='Seasons',y='Rented Bike Count',hue='Holiday',dodge=True,jitter=True,data=df)
# Out:
# <Axes: xlabel='Seasons', ylabel='Rented Bike Count'>

# %% [markdown]
# form this plot we can say that in every season on working day bike rented is high as compare to non working days people rent bike instad of any other transport

# %%
df['Date']=pd.to_datetime(df['Date'], dayfirst=True, errors='coerce')
df['Month']=df.Date.dt.month_name().str[:3]
df['Year']=df.Date.dt.year
df['Weekday']=df.Date.dt.weekday

df.Weekday=df.Weekday.map({
    0: "Monday",1: "Tuesday",2: "Wednesday",
    3: "Thursday",4:"Friday",5:"Saturday",6:"Sunday"
})

df["Weekday"] = pd.Categorical(
    df["Weekday"],
    categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'],
    ordered=True
)

df.head()
# Out:
#         Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0 2017-12-01                254     0             -5.2           37
# 1 2017-12-01                204     1             -5.5           38
# 2 2017-12-01                173     2             -6.0           39
# 3 2017-12-01                107     3             -6.2           40
# 4 2017-12-01                 78     4             -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# 0               2.2              2000                      -17.6
# 1               0.8              2000                      -17.6
# 2               1.0              2000                      -17.7
# 3               0.9              2000                      -17.6
# 4               2.3              2000                      -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
sns.displot(data=df ,x ='Wind speed (m/s)')

# %% [markdown]
# this shows that when the wind speed is very high the bike count decreses as it get harder for bikers to ride a bike due to high speed wind

# %%
sns.barplot(x='Weekday', y='Rented Bike Count', data=df  )
# Out:
# <Axes: xlabel='Weekday', ylabel='Rented Bike Count'>

# %% [markdown]
# this helps to analysis that on the off day thats sunday the bike count is less as discussed in previous graph that on off day the bike count is low this proof that most of the people who rent the bike are working peoples , school going students

# %%
sns.barplot(x='Month', y='Rented Bike Count', data=df)
# Out:
# <Axes: xlabel='Month', ylabel='Rented Bike Count'>

# %% [markdown]
# this graph show that the most or the tress full months for the workers , students was jun as rented bike count is getting high only in jun  as compare to other months

# %% [markdown]
# it also shows that the free months was jan , feb , dec

# %%
sns.lineplot(x='Year', y='Rented Bike Count', data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Rented Bike Count'>

# %% [markdown]
# this shows the trent of bike rent increses and according to that we can tell be just looking at it that business is gorwing
