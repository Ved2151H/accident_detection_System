# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mtb
import seaborn as sns

# %%
sf = pd.read_csv(r'csv files and datasets/SeoulBikeData.csv')

# %%
sf.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# ...

# %%
sf['Rented Bike Count'].mean()
# Out:
# 704.6020547945205

# %%
sf['Temperature(C)'].max()
# Out:
# 39.4

# %%
sf['Hour'].mean()
# Out:
# 11.5

# %%
sf['Rented Bike Count'].max()
# Out:
# 3556

# %%
sf['Rented Bike Count'].sum()
# Out:
# 6172314

# %%
sf['Hour'].max()
# Out:
# 23

# %% [markdown]
# Finding the total hrs

# %%
mtb.plot(sf['Rented Bike Count'], sf['Hour'])

# %% [markdown]
# ***The above graph shows r**elationship between the Rented Bike Count and hour. That is basically the time at which the max number of bikes are rented.***

# %%
sf.tail()
# Out:
#             Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 8755  30/11/2018               1003    19             4.2           34
# 8756  30/11/2018                764    20             3.4           37
# 8757  30/11/2018                694    21             2.6           39
# 8758  30/11/2018                712    22             2.1           41
# 8759  30/11/2018                584    23             1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 8755               2.6              1894                     -10.3
# 8756               2.3              2000                      -9.9
# 8757               0.3              1968                      -9.9
# 8758               1.0              1859                      -9.8
# 8759               1.3              1909                      -9.3
#
#       Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons  \
# ...

# %%
sf['Date']=pd.to_datetime(sf['Date'])
sf['Month']=sf.Date.dt.month_name().str[:3]
sf['Year']=sf.Date.dt.year
sf['Weekday']=sf.Date.dt.weekday
sf.Weekday=sf.Weekday.map({0: "Monday",1: "Tuesday",2: "Wednesday" ,3: "Thursday",4:"Friday",5:"Saturday",6:"Sunday"})
sf["Weekday"] = pd.Categorical(sf["Weekday"], categories=
    ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday'],
    ordered=True)
sf.head()
# Out:
# /home/silver/.local/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '13/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/silver/.local/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '14/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# /home/silver/.local/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '15/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      8760 non-null   datetime64[ns]
#  1   Rented Bike Count         8760 non-null   int64
#  2   Hour                      8760 non-null   int64
#  3   Temperature(C)            8760 non-null   float64
#  4   Humidity(%)               8760 non-null   int64
#  5   Wind speed (m/s)          8760 non-null   float64
#  6   Visibility (10m)          8760 non-null   int64
#  7   Dew point temperature(C)  8760 non-null   float64
#  8   Solar Radiation (MJ/m2)   8760 non-null   float64
#  9   Rainfall(mm)              8760 non-null   float64
#  10  Snowfall (cm)             8760 non-null   float64
#  11  Seasons                   8760 non-null   object
#  12  Holiday                   8760 non-null   object
# ...

# %%
fig,((ax1,ax2),(ax3,ax4)) = mtb.subplots(2,2,figsize=(16,8), gridspec_kw={'hspace': 0.3})

sns.barplot(data=sf,x="Seasons",y="Rented Bike Count",palette="colorblind",ax=ax1,ci=None)
# sns.barplot(data=sf,x="Wind speed (m/s)",y="Rented Bike Count",palette="colorblind",ax=ax1,ci=None)
sns.lineplot(data=sf,x="Month",y="Rented Bike Count",palette="colorblind",ax=ax3,ci=None)
sns.barplot(data=sf,x="Weekday",y="Rented Bike Count",palette="colorblind",ax=ax2,ci=None)
sns.lineplot(data=sf,x="Hour",y="Rented Bike Count",color="tab:blue",ax=ax4,ci=None)
ax1.set_title("Seasonal Bike Rents")
ax3.set_title("Monthly Bike Rents")
ax1.set_xlabel("")
ax3.set_xlabel("")
ax2.set_title("Weekday Bike Rents")
ax4.set_title("Hourly Bike Rents")
ax2.set_xlabel("")
mtb.savefig("Timeline.png",dpi=300)

mtb.show()
# Out:
# /tmp/ipykernel_13770/422974386.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=sf,x="Seasons",y="Rented Bike Count",palette="colorblind",ax=ax1,ci=None)
# /tmp/ipykernel_13770/422974386.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=sf,x="Month",y="Rented Bike Count",palette="colorblind",ax=ax3,ci=None)
# /tmp/ipykernel_13770/422974386.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=sf,x="Month",y="Rented Bike Count",palette="colorblind",ax=ax3,ci=None)
# /tmp/ipykernel_13770/422974386.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=sf,x="Weekday",y="Rented Bike Count",palette="colorblind",ax=ax2,ci=None)
# /tmp/ipykernel_13770/422974386.py:7: FutureWarning:
#
# ...

# %% [markdown]
# ***Seasonal Bike Rents***
# **Lets take a look at the first chart. From the given bar plot we can clearly see that the rented bike count is less in winters being highest in the summer followed by Autumn and Spring. From the graph we can make an assumption that people like to rent bikes when temperature is higher, but we can also say that in seoul many students have summer vacations, so they use rented bikes to visit places or commute to their summer camps**
#
# ***Weekly Bike Rents***
# **Now lets move over to the Weekly graph. From the graph it is clearly visible that there is a rise in the number of the rented bikes and it declines on Sunday which is day off to maximum students and employees**
#
# ***Monthly Bike rents***
# From this graph it is clearly visisble that there Is slow rise in the count of rented bikes from the months January to Febuary and it begins to rise from february and peeks at the starting weeks of June and begins declinig From june till September. This is probably due to the start of the rainy season, it is hard and less safe to ride bikes in the rainy season so most of them prefer using a public transport or a car or prefer commuting to their respective destination with an umbrella. The count begins to rise as the rainy seasons ends and the fall/autumn begins to start as it is the time of the year marked with clear skys. And after seeing the peek in October it begans to fall down as the temperature begins to fall and Winter approaches.
#
#
# ***Hourly Bike Rents***
# By taking a look at this graph it can be clearly seen that there is a sharp rise in the mornung hours that is between 6 to 10 and evening hours 4pm to 7 pm. It can be deducted from this graph that the maximum rented bikes are used by students and employees who commute from home to their respective destinations in the morning and vice versa in the evening.

# %%
sf['Year'] = sf['Date'].dt.year
sf['Month'] = sf['Date'].dt.month
sf['Day'] = sf['Date'].dt.day
sf.head(20)
# Out:
#          Date  Rented_Bike_Count  Hour  Temperature  Humidity  Wind_speed  \
# 0  2017-01-12                254     0         -5.2        37         2.2
# 1  2017-01-12                204     1         -5.5        38         0.8
# 2  2017-01-12                173     2         -6.0        39         1.0
# 3  2017-01-12                107     3         -6.2        40         0.9
# 4  2017-01-12                 78     4         -6.0        36         2.3
# 5  2017-01-12                100     5         -6.4        37         1.5
# 6  2017-01-12                181     6         -6.6        35         1.3
# 7  2017-01-12                460     7         -7.4        38         0.9
# 8  2017-01-12                930     8         -7.6        37         1.1
# 9  2017-01-12                490     9         -6.5        27         0.5
# 10 2017-01-12                339    10         -3.5        24         1.2
# 11 2017-01-12                360    11         -0.5        21         1.3
# ...

# %%
sf.columns=sf.columns.str.replace(r"\(.*\)","").str.strip().str.replace(" ",'_')
# Out:
# /tmp/ipykernel_13770/2310669369.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   sf.columns=sf.columns.str.replace(r"\(.*\)","").str.strip().str.replace(" ",'_')

# %%
sns.countplot(x="Day", data=sf)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='count'>

# %% [markdown]
# From the above graph it is clear that the count of the bikes decreases at the end of the month

# %%
sns.countplot(x="Year", data=sf)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# Since the dataset contains the count and data of the years 2017 and 2018, it clearly visible that the count of bike was more in 2018 as compared to 2017, which incicates the increase of the popularity of the rental bikes in Seoul

# %%
sns.countplot(x="Month", data=sf)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %% [markdown]
# There is no particular change in the count of bikes in each month

# %%
mtb.figure(figsize=(12,4), dpi=100)
sns.lineplot(data=sf, x="Hour", y="Rented_Bike_Count", hue="Seasons")
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Rented_Bike_Count'>

# %% [markdown]
# The above graph displays the hourly count of the bikes with respect to the different seasons. It is clear that the the majority count of the bikes in the morning and evening hour indicates that most of them are rented by the students and employees to commute to their respective study and work places.

# %% [markdown]
# ### Question 3  part c
# ## 12014917 Gaurav Patel using the seol bike data

# %%
u_var=sf.iloc[:,1:-3].corr()
sns.heatmap(data=u_var)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap we can see the corelation between the Rented bike count and the other Whether factors affecting the bike count. It is clear from the plot that the Bike count is majorly affected by the Temperature, Humidity,Visiblity and Solar Radiation.

# %%
sns.scatterplot(y='Rented_Bike_Count',x='Temperature',data=sf)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Rented_Bike_Count'>

# %% [markdown]
# The rental bike count decreases when the temperature drops below 0. People avoid to rent bikes on lower temperatures that is the count is usally less in the winter months, ans most of them prefer public or private transports.

# %%
sns.scatterplot(x='Rented_Bike_Count',y='Dew_point_temperature',data=sf)
# Out:
# <AxesSubplot:xlabel='Rented_Bike_Count', ylabel='Dew_point_temperature'>

# %% [markdown]
# The rental bike count is less for lower dew point temperatures.

# %%
sns.displot(sf['Visibility'])

# %% [markdown]
# **Peolple preffer to rent bike when the visibility is good**

# %%
sns.displot(sf['Wind_speed'])

# %% [markdown]
# **We can see that as the wind speed increases the number of bike count decreases as it makes it harder to ride the bikes against the wind, whereas when the wind speed is between 0 to 3 there is a fair increase in the count of bikes as the people find it pleasent to ride bikes when the wind speed is normal.

# %%
sns.displot(sf['Snowfall'])

# %% [markdown]
# **it can be depicted that bike count is more when there is no or less snowfall, compared to when there is heavy or medium snowfall. It can be concluded that it is harder to ride bikes in the areas of snowfall as it makes people prone to accidents**

# %%
sns.displot(sf['Rainfall'])

# %% [markdown]
# ** the same can be said to rainfall as said for snowfall, cause it has the same reason, it is harder to ride the bikes when there is heavy rainfall cause it makes harder to ride bikes and cause accidents.**

# %%
sns.scatterplot(y='Rented_Bike_Count',x='Snowfall',data=sf)
# Out:
# <AxesSubplot:xlabel='Snowfall', ylabel='Rented_Bike_Count'>

# %%
sns.scatterplot(y='Rented_Bike_Count',x='Rainfall',data=sf)
# Out:
# <AxesSubplot:xlabel='Rainfall', ylabel='Rented_Bike_Count'>

# %% [markdown]
# From the above graphs of rainfall, snowfall,wind speed and visibilty, it is clear that people prefer to rent out bikes when the visibilty is higher, the wind speed is normal, there is less rainfall and snowfall.

# %%
sns.stripplot(x='Seasons',y='Rented_Bike_Count',hue='Holiday',dodge=True,jitter=True,data=sf)
# Out:
# <AxesSubplot:xlabel='Seasons', ylabel='Rented_Bike_Count'>

# %% [markdown]
# From the above plot we can see that in each season the rental bike count is less on Holidays as compared to the no holidays or the working days. People prefer to rent bikes on the working days instead of using the public or private transport

# %%
sns.boxplot(x=sf['Hour'], y=sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Rented_Bike_Count'>

# %% [markdown]
# As discused earlier we can see that the count spikes at the time between 6 to 10 and 15 to 23 because during the morning time both students and employees need to commute to their work places and after afternoon the count of employees is more than students because there are many people who work part time and also more of the people work in cooperate and private sectors

# %%
sns.boxplot(x=sf['Seasons'], y=sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:xlabel='Seasons', ylabel='Rented_Bike_Count'>

# %% [markdown]
# ### The count of bikes is more in summer because it is the ideal season to commute through bikes and people

# %%
sns.boxplot(x=sf['Functioning_Day'], y=sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:xlabel='Functioning_Day', ylabel='Rented_Bike_Count'>

# %% [markdown]
# ### The count of rented bike is to be expected more on the function day ofourse because on the non the nonfunction day the bikes are either out for maintainance or the renting places are under check

# %%
sns.boxplot(x=sf['Weekday'], y=sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='Rented_Bike_Count'>

# %% [markdown]
# ### the count of the rented bikes is less on sunday because it is a day off and most people prefer to stay at home and relax

# %%
sns.boxplot(x=sf['Month'], y=sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Rented_Bike_Count'>

# %% [markdown]
# ### there is apeek in the count of rented bikes from april to june because it is the summer season and the days are clear and the wind is perfect for riding the bikes. while there is sa drop in the count of bikes in winter and rainy season since it is difficult to ride bikes in snow and rainfall when the visibility is less and its hard to ride the bikes

# %%
sns.boxplot(x=sf['Year'], y=sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Rented_Bike_Count'>

# %%
sns.boxplot(x=sf['Holiday'], y=sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:xlabel='Holiday', ylabel='Rented_Bike_Count'>

# %%
sns.scatterplot(sf)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(sf)

# %% [markdown]
# I can reach to the conclusion that more people are now shifting to rented bikes as they are more convinient portable and they decrease the pollution caused by the vehicles and public transports. And people cam reach their respective destinations at time and they can stay healty too

# %% [markdown]
# ### Qeustion 3 part a
# ## 12014917 Gaurav Patel using seol bike data

# %%
sns.histplot(sf)
# Out:
# <AxesSubplot:ylabel='Count'>
# /home/silver/.local/lib/python3.10/site-packages/IPython/core/events.py:89: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /home/silver/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.boxplot(sf['Rented_Bike_Count'])
# Out:
# <AxesSubplot:>
